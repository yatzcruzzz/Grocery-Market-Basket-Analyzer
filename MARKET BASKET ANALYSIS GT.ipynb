# %%
# !pip install mlxtend

# %%
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori, association_rules

# %%
data = pd.read_csv('Groceries_dataset.csv')

# %%
data.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %% [markdown]
# # DATA EXPLORATION

# %%
x = data['itemDescription'].value_counts().sort_values(ascending=False)[:10]

# %%
x
# Out:
# itemDescription
# whole milk          2502
# other vegetables    1898
# rolls/buns          1716
# soda                1514
# yogurt              1334
# root vegetables     1071
# tropical fruit      1032
# bottled water        933
# sausage              924
# citrus fruit         812
# Name: count, dtype: int64

# %%
item_counts = pd.Series({
    'whole milk': 2502,
    'other vegetables': 1898,
    'rolls/buns': 1716,
    'soda': 1514,
    'yogurt': 1334,
    'root vegetables': 1071,
    'tropical fruit': 1032,
    'bottled water': 933,
    'sausage': 924,
    'citrus fruit': 812
}, name='count')

# %%
item_counts_df = item_counts.reset_index()
item_counts_df.columns = ['itemDescription', 'count']

# %%
plt.figure(figsize=(15, 10))
sns.barplot(x='itemDescription', y='count', data=item_counts_df, palette='viridis')
plt.xticks(rotation=45)  # Rotate x labels for better readability
plt.title('Top 10 Most Frequent Items')
plt.xlabel('Item Description')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # APRIORI ALGORITHM (Support,Confidence,Lift)

# %%
data
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
data ['Quantity']= 1

# %%
data
# Out:
#        Member_number        Date        itemDescription  Quantity
# 0               1808  21-07-2015         tropical fruit         1
# 1               2552  05-01-2015             whole milk         1
# 2               2300  19-09-2015              pip fruit         1
# 3               1187  12-12-2015       other vegetables         1
# 4               3037  01-02-2015             whole milk         1
# ...              ...         ...                    ...       ...
# 38760           4471  08-10-2014          sliced cheese         1
# 38761           2022  23-02-2014                  candy         1
# 38762           1097  16-04-2014               cake bar         1
# 38763           1510  03-12-2014  fruit/vegetable juice         1
# 38764           1521  26-12-2014               cat food         1
#
# [38765 rows x 4 columns]

# %%
transactions= data.groupby(['Member_number','itemDescription'])['Quantity'].sum().unstack().reset_index().set_index('Member_number')

# %%
transactions.fillna(0)
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               0.0       0.0               0.0
# 1001                               0.0       0.0               0.0
# 1002                               0.0       0.0               0.0
# 1003                               0.0       0.0               0.0
# 1004                               0.0       0.0               0.0
# ...                                ...       ...               ...
# 4996                               0.0       0.0               0.0
# 4997                               0.0       0.0               0.0
# 4998                               0.0       0.0               0.0
# 4999                               0.0       0.0               0.0
# 5000                               0.0       0.0               0.0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
def encode(x):
    if x <=0:
        return 0
    elif x>=0:
        return 1
basket = transactions.applymap(encode)

# %%
basket
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               NaN       NaN               NaN
# 1001                               NaN       NaN               NaN
# 1002                               NaN       NaN               NaN
# 1003                               NaN       NaN               NaN
# 1004                               NaN       NaN               NaN
# ...                                ...       ...               ...
# 4996                               NaN       NaN               NaN
# 4997                               NaN       NaN               NaN
# 4998                               NaN       NaN               NaN
# 4999                               NaN       NaN               NaN
# 5000                               NaN       NaN               NaN
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
basket.fillna(0)
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               0.0       0.0               0.0
# 1001                               0.0       0.0               0.0
# 1002                               0.0       0.0               0.0
# 1003                               0.0       0.0               0.0
# 1004                               0.0       0.0               0.0
# ...                                ...       ...               ...
# 4996                               0.0       0.0               0.0
# 4997                               0.0       0.0               0.0
# 4998                               0.0       0.0               0.0
# 4999                               0.0       0.0               0.0
# 5000                               0.0       0.0               0.0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
basket = basket.fillna(0)

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
frequent_itemset = apriori(basket,min_support=0.06,use_colnames=True)
rules = association_rules(frequent_itemset,metric='lift',min_threshold=1)
# Out:
# C:\Users\Yasharth Srivastava\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
rules.head()
# Out:
#           antecedents         consequents  antecedent support  \
# 0        (whole milk)              (beef)            0.458184
# 1              (beef)        (whole milk)            0.119548
# 2  (other vegetables)      (bottled beer)            0.376603
# 3      (bottled beer)  (other vegetables)            0.158799
# 4      (bottled beer)        (rolls/buns)            0.158799
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.119548  0.064135    0.139978  1.170886  0.009360    1.023754
# 1            0.458184  0.064135    0.536481  1.170886  0.009360    1.168919
# 2            0.158799  0.068497    0.181880  1.145345  0.008692    1.028212
# 3            0.376603  0.068497    0.431341  1.145345  0.008692    1.096257
# 4            0.349666  0.063109    0.397415  1.136555  0.007582    1.079240
#
#    zhangs_metric
# 0       0.269364
# 1       0.165762
# 2       0.203563
# 3       0.150857
# 4       0.142829

# %%
rules[(rules['confidence']>0.4)]
# Out:
#                         antecedents         consequents  antecedent support  \
# 1                            (beef)        (whole milk)            0.119548
# 3                    (bottled beer)  (other vegetables)            0.158799
# 7                    (bottled beer)        (whole milk)            0.158799
# 9                   (bottled water)  (other vegetables)            0.213699
# 15                  (bottled water)        (whole milk)            0.213699
# 19                    (brown bread)        (whole milk)            0.135967
# 21                         (butter)        (whole milk)            0.126475
# 22                    (canned beer)  (other vegetables)            0.165213
# 24                    (canned beer)        (rolls/buns)            0.165213
# 26                    (canned beer)        (whole milk)            0.165213
# 29                   (citrus fruit)  (other vegetables)            0.185480
# ...
